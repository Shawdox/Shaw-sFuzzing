# %%
import subprocess
import random
from typing import Union,List

# %%
print (\x6C5CEC9)
# Out:
#   File "C:\Users\Shaw\AppData\Local\Temp/ipykernel_1788/2607075840.py", line 1
#     print (\x6C5CEC9)
#                     ^
# SyntaxError: unexpected character after line continuation character

# %%
class Runner:
    PASS = "PASS"
    FAIL = "FAIL"
    UNRESLOVED = "RESELOVED"

    def __init__(self) -> None:
        pass
    def run(self,inp:str):
        return (inp,Runner.UNRESLOVED)

class ProgramRunner(Runner):
    def __init__(self,program: Union[str,List[str]]):
        self.program = program
    def run_process(self,inp:str = ""):
        return subprocess.run(self.program,
                              input = inp,
                              stdout = subprocess.PIPE,
                              stderr = subprocess.PIPE,
                              universal_newlines=True,
                              shell=True
                              )
    def run(self,inp:str = ""):
        result = self.run_process(inp)
        
        if result.returncode == 0:
            outcome = self.PASS
        elif result.returncode < 0:
            outcome = self.FAIL
        else:
            outcome = self.UNRESLOVED
        return (result, outcome)
    

class BinaryProgramRunner(ProgramRunner):
    def run_process(self, inp: str = "") -> subprocess.CompletedProcess:
        """Run the program with `inp` as input.  
           Return result of `subprocess.run()`."""
        return subprocess.run(self.program,
                              input=inp.encode(),
                              stdout=subprocess.PIPE,
                              stderr=subprocess.PIPE)

# %%
class Fuzzer:
    def __init__(self) -> None:
        pass
    def fuzz(self) -> str:
        return
    def run(self,runner:Runner = Runner()):
        return runner.run(self.fuzz())
    def runs(self,runner:Runner = Runner(),trials:int = 10):
        return [self.run(runner) for i in range(trials)]
    
class RandomFuzzer(Fuzzer):
    def __init__(self,min_length:int = 20,max_length:int = 20,
                 char_start:int = 32,char_range:int = 32):
        self.minlen = min_length
        self.maxlen = max_length
        self.start = char_start
        self.range = char_range

    def fuzz(self):
        string_len = random.randrange(self.minlen,self.maxlen+1)
        out = ""
        for i in range(0,string_len):
            out +=chr(random.randrange(self.start,self.start+self.range))
        return out

# %%
random_fuzzer = RandomFuzzer(min_length=20, max_length=20)
for i in range(10):
    print(random_fuzzer.fuzz())
# Out:
# 5)#2;6#5<$")3+)99333
# "50#0>8=3 <$0'+!-?,"
# 95!$7'>(2-9/&%"2'%->
# 1< .&'2+''31"1*"-./2
# !69?/5$39, +-7(%)62!
# 130>4)3;9,37>,.-%+?1
# ">9$1,)'?:-;%&)6>*<4
# 08);6&)?(!$?" -%<**!
# 4/3/>#/!8"(:78*10=<1
# <$9 !0=96;,$326)17=1

# %%
cat = ProgramRunner(program='cat')
cat.run('hello')
# Out:
# (CompletedProcess(args='cat', returncode=0, stdout='hello', stderr=''), 'PASS')

# %%
random_fuzzer.run(cat)
# Out:
# (CompletedProcess(args='cat', returncode=0, stdout='?>15"/;24<9=0:!*><,1', stderr=''),
#  'PASS')

# %%
inp = random_fuzzer.fuzz()
cat.run(inp)
# Out:
# (CompletedProcess(args='cat', returncode=0, stdout='*19$ -9.48 8 ):;8=50', stderr=''),
#  'PASS')

# %%
#Exercise 2:Run Simulated Troff
class TroffRunner(Runner):
    def __init__(self):
        self.f1_failures = 0
        self.f2_failures = 0
        self.f3_failures = 0
    
    def f1(self,s: str):
        index = s.find('\\D')
        while(index != -1):
            assert s[index+2:index+3].isprintable()
            s = s[index+2:]
            index = s.find('\\D')
        return True
    
    def f2(self,s: str):
        for i in range(len(s)-1):
            if ord(s[i]) >= 128 and ord(s[i]) <= 255:
                assert s[i+1:i+3] == '\n'
        return True

    def f3(self,s: str):
        assert s != ".\n"
        return True
    
    def run(self,inp:str):
        try:
            self.f1(inp)
        except AssertionError:
            self.f1_failures +=1

        try:
            self.f2(inp)
        except AssertionError:
            self.f2_failures +=1

        try:
            self.f3(inp)
        except AssertionError:
            self.f3_failures +=1

        return inp

# %%
troff_fuzzer = RandomFuzzer(char_start=0, char_range=256,min_length=1 ,max_length=20)
troff_runner = TroffRunner()

# %%
troff_fuzzer.runs(troff_runner, trials=100000)
# Out:
# ['Àèõ\x05a',
#  'E\x97gxt\x936\x82',
#  'CÎ\x89\x84@\x12\x1a0D×¬Uõg£rp',
#  '`\x19\r?F°f',
#  '¾KÛLA?Ø§|\x8bÖ{{|ðJ÷òú',
#  '\x10>\x0fë\num.\x8cÓã½',
#  '½Î',
#  '\x92/{kÚªÉaü\x12\x93¬',
#  '<*U19S¤\xadÒ.\x0f¹\x8dîÄ´',
#  '\x0cì\x19+$·o¨PMe\x0c\x0f\x1a®Î]Ë<',
#  'Ô\xad',
#  "LLÊ¢b\x1b¶\x88À©´\x1c«iÑtá'#",
#  '¾',
#  'î\x11TM\x10\x96Â<\x81b%¤IWíZ\x8b',
#  'çÞdI\x8aS\x18*Ê8jC#\x80\x86\x8fËÓ',
#  '[dZ#ó\x01Úèð\x9b',
#  '¼\x01',
#  '\x04\x05ÈÆ\x86À\x02',
#  '6UÑC¸\x96\x8chÊ]\x0f%êg',
#  'Fk>"-Rý¼½c¤\x12\x8a',
#  'Jí+~éSñ§L',
#  '\x99f\x93',
#  '\x05§=\x1a#\x1a\x9a\x89ýî',
#  'j]Õ×\x930áÝQ',
#  '\x90;Z×r=OK1\x83þ\x87z\x14.px¥',
#  '\x0byüÖÈQÙµ\x00²\x880\x83Öîã\x10\x9e\x08',
#  'úIö}@¼&\x03õ\x86ÈñbRqóO±\x8d',
#  'üÙR\x00g',
#  'Ì\x0b3T|Õ\x8c;\x04ª4Ê|ÕpÈ{\x08',
#  'ûå(´Îw',
#  'lEÐ,"\x99\x94 \x96\x14\x17¹ò\x1f\x9c\x1b\x97',
#  'óÊ\x10',
#  'A¹9Þ\x00Ï\x9f~V\x18\x9d£',
#  's',
#  '~aÒU\x0643ê=&Å',
#  'Ñ\x14*µ÷²£¤¥-\\',
#  '×²}}u\x12\x19\x13Æ\x1bnAA\x9cºA\x84X\x1e\x1b',
#  'ôÅ\x17æ\x8dÌ¶\x83í\x05ïø\x8dU',
#  'txî£¿üF*ØèÞ¥_',
#  '®XPÉ\tG%SvMå\x00\x08ô',
#  'bD\x94çÕTy\x7fô\x902Ë',
#  'âïô\x1fþúÎß#T_¬_\x10Kö\xad\x95é',
#  'ðx\x98n®~ÖÏfvÄ3\x19\xad)\x8f\x93\x8e',
#  '\x8cGdp\x19\x01\x17À-\x0eZ',
#  '?H¤',
#  'û\x18',
#  's~ã,óéF',
#  "\rÕ³n4\x0cÝ@Gª¶\n{kb'Ð\x80¶É",
#  'Ùÿ\\¿ÄºRvÛ\x1f¢\x8d§',
#  'î',
#  '\x8d¾ú',
#  'c_CÏ\x7fê¡¦',
#  '¨ª\x12uÑ\x1eðs4\xa0',
#  '\x93Cý\x14Y±ôÙ',
#  'ð?À\x19ÜÓ½®Tvñ Öó<]ãÍ',
#  'ëÕÍóêë\x12\x7f%\x80\xa0\x9fS#\x04±\x86É',
#  '\x14fkB8FAÚw\x13´F1',
#  '\x97\x13',
#  'Çs§±',
#  'Y+X',
#  'G*\x9d)]¬×Öè\x1e[Dk\x87 A\x94',
#  '\nKõË¨\x8bÿS¼),\nòCá',
#  'bÁø\tü÷\x9d¬ÛDÝÙ',
#  '\x15´jfI',
#  '{B\x85C\x97\x11ª:\x99\x17KÌ\x13\x02êæ',
#  '\x8d',
#  '.ÊÀ÷',
#  'LÙ\x08Á!÷ö\x86¸\x8avy\x01\x99\x8c\nì ',
#  'ÁÛp\\ù\x9b\x11÷d\x04«\x17\nnýÒ»Â¾¬',
#  '\x00MÔ~zæ\x9d\x82u\x92',
#  'XØQa\xad³\x04wQÁÇ\x1a<Ð\x8f',
#  'ØÙ øèÜÇF\x9cBÜ2Ûöl\x05|2Ö',
#  '±L.Ý\x8e\x80ÿ\\\x9f',
#  '-V}\x85W0]k\x17\x0c³ô',
#  '\x83',
#  '\x1fn\x1by\x9e\x02\x86\x02ÈA\x8cM\\ÂÂ',
#  'ä¦z',
#  'î\x0eèS\x02\x89\x9b×¢ªPí[B)ó\x80 \xa0ý',
#  '_¯QÜ¡\x0b&u',
#  '\x8fÁ±Â\x05ÛÃÉMµ\x1e\x86¼Æ)\x96\x14\x8eÇ',
#  '\x0f+`\x86Þ',
#  "óÿ+@]J\x01\x14¼?\x95£Ó'Ìææ2\x97×",
#  '\x88',
#  'è\x05c\x937Oç*',
#  '\t\x81Ç¯O&r\xa0F8®/w\x0e\t',
#  '\x06V\x90~\\¨\x03¶\x8f®\\\x1c\x10\x9f',
#  '\x13KSß»\x0e\x8eÓ©¼\x12\x1f\x1dM\xad\x13Ù',
#  'â0\x141â\x99î =9\x97\x16å(¡',
#  '&\x83\x9f',
#  'b\x86iìB\x84¿((\x9bÌ',
#  '&\x8c\x18L',
#  '\x87Î\r/¤\x94±ù¼\x99\x87ÿÅv]%',
#  'Üõ\n',
#  '\x81\x1e\x89à\x80\x1c\x9f\x01s4Y\xa0\x9d\x17¹\x86ÐZ\x0b',
#  '¹\x1e\x1e',
#  'vÝX¬\n\x87Ý\x8d\x81×',
#  'Bå\x12v*\x95µææ>C\x13õÿ\x07_o',
#  '\x1bk<{\x0blÞ\x14CÍ×CÙ\\5O',
#  '\x91\x0e\x84\x00¨',
#  '[\x9e¬\x0fp÷\rç',
#  '\x80èNæ\x15á·ñBn\x0cO',
#  ':ßÊód/Ç.ü¯\x92Î²\t',
#  '\xad',
#  'A\x03\x92\x05\x0by?\x9b',
#  '¤é\x13ôs¨@Ö\x1fr\x9e¤êP¦',
#  'Ï\\\x04&G',
#  '\x8cÜ¤yêÈ=¦\x82\n\x0bé]ê\x81,\x13\x9c\x1bn',
#  'Fc',
#  'd·\x1e\x081<ÜPÕ',
#  'ü.\x07)kè¦',
#  'ê0ñZç\x82/ÍÆàí\x92\x9c>*ì\x1a÷[þ',
#  'øK]K~*2DPw"~ö¾²\x84\x13:Ê',
#  '\x9cüÊþi',
#  '.',
#  '\x86=',
#  'Âx?Ñ',
#  '[j»\x97ÿÛ/ïJÜîAW¾6¤\x14\x92',
#  '\x8dýûz\x82 ×v±\x1e',
#  'ã%A9',
#  '=?',
#  '\x84>:ì\x8a',
#  '³',
#  '{k\x0c¦\x08Oñ',
#  '\x0eª"TÔ¡í',
#  '@<Ô',
#  '\x15^È^\x8d\x1f\x03\x1b@rà\x18',
#  '¸ãùÄ;¿ÂÔ§»',
#  '\x81\x99J\x15\x19ø\x884øyD\x05WÃ*tJ\x84×S',
#  '1\x85\x10Ç\x0f \x98é',
#  'E\x02\x03\x8aÍ]Ü\x0f\x12dp\x00eè¼Îe',
#  '¨\x15Ù{4\x98Ü\x102',
#  'ú\x8f\nz\x84\x00Ed\x19òÎ',
#  'TÅµ\x98@\x9d(',
#  '\x1cr\x81\x7f',
#  'ÐÂÚâ\x9fhÓm\x16ÏÔ×D\x18È',
#  '3Øe½ç\x04ârYµäE¢v\x94´',
#  'Ê±Xµ\x0cÎ}\x11C\x12hÍª¡°m',
#  'Évb+1\x12\x0c\x0c¯Gq\x92b»È',
#  'EÊæa\x03\xadÐ',
#  'î±\t\x9b\x8döx\x1eòÎ\x03\x89Ä\x10§û\x1cF³',
#  '\x0b\x00',
#  'ÐI\x89\x18',
#  'tá',
#  '\x00Et«îúÈl',
#  '¤ó^<\x15\x0f\x90(ÑÅy\x82ý-\x8d\x8c',
#  'Ú\x17w¹\x1a\x19É!',
#  '\x10;\x0f¤ 5\x1b',
#  '(G¢èl\x8b\x82³',
#  '\x85Õ\x1eh\x80ÊÒa«Ö\x1fM\x1fî[Ë\x8b',
#  '6@KÇ¤ä',
#  'Ëä\x06£\x19\xad\xad',
#  'F®n',
#  'XèÏ[Í\t%ÄÖ÷\x8f\x00\x92túç',
#  'RàÚñ(K\x80\x88Í¸\x0b\x91o',
#  ')É7+\x97Ù¾1\x90¢.å',
#  '\x0b³',
#  '\x0e4Ñ\x1c$l\x93\x1c±cR]øß\x1fs\x0b\x8eÄÄ',
#  'á\x93b°I¡Öx6',
#  'ËÀíÈÅbÆ\x99à.',
#  '\x01\x83\x1d\x04}uë:\x11§Ê"É\xad',
#  '\x04¿\x90Væ/4',
#  '\x99»êÅ\x18I{Ô\x8a',
#  ']ó&¯©\x14N÷ó\x9aÃþ4l\x85',
#  '\xad\x916â\x03ÿ\x17\x17¾»q.Ø\x9a[w\x85Dq_',
#  'àÿ\x18n´[È\x02ÿ\x94û\x81h\x93`vºGÙ',
#  'Ã\x03Ï S°Ìé@g\x16¯{\x15ó=ÃÅ',
#  '`?=¬9£\x9bI\x92éã\x1dªå¯õ',
#  'Þ\x8bª',
#  '\x00Ê\x1b\x1c¿b÷Ö#s\x0fh',
#  '\x92\x9b\x16Wº\x81@\x86÷y)ÄD,á\x06·±z¹',
#  '\x84\x12\x88Ú&',
#  '\x81òc£\\VZ\x06\x8amoAâ',
#  '¼\x8bñ\x0b©[»T\x8f#4\x8f;\x8a3ú',
#  'ñY2',
#  '`\x17',
#  '¸)-·®\x80K\x94Æ\x9e\xa0]',
#  '\x1fâ\x8f',
#  'Ããh:',
#  '?ÂÁÑÛKák9\x88\x13',
#  '\x7f\x1a@^\x0f´ÝïÁãq\x1e?3',
#  '\x14\x9eYyÏGQâ°¤S\x0e\x02ârã2C6',
#  '/+øÎ®o\x10ÙCÛõ=\x01',
#  'ñ°.v\x10ï\x98\x97V\x0cF\x90\x95\\\x9c',
#  '8àÎÂ@$\x84ÃK(F´û\x16äCÀG',
#  'j',
#  'Äõ\x8ee\x01ø\x8b',
#  'ÿî¢É\x1cn®\x80[\x93ú«Åá"2Eä',
#  'YÙsh\x8e\x1a^VîíúOVG\x94',
#  '·ÿù9Øï\x8e*\x07j\x8dÂ[u\x9a1*[«',
#  'R\x92W\x0b\x1f\x1bë"\x99x¶ï\x8av\x7fêU',
#  'ê',
#  '3J\x8f¢\x1ay+«ÚYÝº,i\x0e*å\x04\x0c\x02',
#  's\x92\xadK¡©Ï\x90\x96ýÂ\x05çs',
#  '¤û',
#  'O\x96ó',
#  '\x0ek\x19J´',
#  'Ìw\x0c-ú',
#  'FÕ(¼\x8f\x03Éàpë',
#  'Ê\x05ÆO\nnø¦\x1dø\x9f\x82',
#  '¡=ñ?©\x04hñ×\x83FðËÆ\x90<ÄÁgÿ',
#  'ÑfV\x06\x84Ïmûô\x86ñ?±Û',
#  'M',
#  '\x97tb)',
#  'c\x9auBÕ)\x8b \x03¡Âx',
#  '[\x96ÃI\x8e©Ì¶£',
#  '5\x0c´t¼uÄç{\x81£!¤',
#  '¾\x9eÛjüwB1ûëý¸\x97bi8\x0c0',
#  '\x964e\x1fç¤òÏ\tÎ',
#  '\x14>\xadí+;\x93{á½¹á>\x12÷\x85cQ!',
#  '\x93áä½"Ûß`QQsã\xa0fcN\x1e',
#  'ÚÒ\x0cfüI\x04',
#  '§\x0cl\x0c\xad>»Cã=W9j\x00Ç',
#  '\x0c\x0e\nGbÕ\x7fgÞ#ý',
#  '2µU\x00ïmeÐêÙ©©Ëï',
#  '¨{Cö½ïÄ\x9a¿\x9aì\x9aûµ+$',
#  '±í',
#  "\x9abÙ\x7f/\x94(G\x886]ü'±¨",
#  '\x82"\x81|\x83Yr',
#  'Ù(\x9f<C«',
#  '¬VùM',
#  'j\x1d\x1bÖ',
#  'M»\x91_ó\x1e\x9f',
#  '#\x17H\x88í:a\r*',
#  'c³s\x97\x05S\x1e#kÇ',
#  'Ú\x1dè',
#  ':@\x06É\x0fS\xad´!',
#  'ÃÃP[l\x15\x1aôj\x1cÇXÅÖë',
#  'áy®k¾\x8cé\x99\x02Ã2\x9då\x9f',
#  'i-\x95çop\x93¢ÐÊn',
#  '\x82\x84W\x8cj',
#  'Û(\x84',
#  'u?¢Þ¤×m=Ç\x9cÉI\x87\x9eh÷P2\x88\x89',
#  '®\x81\x8ecyÊ±ù\x1aw g\x9a²x~I',
#  'ôDÏ\x03Åü=Qo£Ä5qDEkf0¸',
#  ',ai¤8\\\x9ar4%\x1d¾1',
#  '\x94ÏÎçxgì\x96à\x91R\x9dö',
#  'É2x\x11:¥\x8c3P²§ò\xa0',
#  'mÉÛCV{c[|$\xa0d\x04\x8a',
#  '\x18L\x9e$\x17<\x12',
#  'Ï\x8cÃb°.\x07ÞU\\á',
#  '¶',
#  "v\x9f,ôucÑ¢2õ²7\x9b\x98½\x89\x08'\x959",
#  '3Afä0ÿ',
#  'ëW&~û|t\x87pËy\x06S]O\x85øÚ¤',
#  'ÝýS5s\x04\xa0-(A',
#  '§5\x86.¾Ñ&;~ó\x85\x18\x84\x14Q/6Ô',
#  'GÜÇ\x89',
#  '\x95\x94\x06-º3n¸',
#  'þãvòxóK\x91m\x1a3\x8f%\x9a´ü',
#  'Õ\x95¡ãCÜ\x7fp',
#  '\x15{cox\r¢ó',
#  'pá\x96·ËU\x82v\x1eï?\x89Í\x8f%.f',
#  '{[Ç\x80¨\x1c\x93[\tÝ\x02S\x84',
#  'Q{RÊ\x1c%9øR@¥\x91\x92t',
#  'x\x14S[I\x93ôöò2¯7\x19Zà|Âh',
#  '\x90\x08pÕd\x89\x9aÁ',
#  'Æ6\x1e\x18F',
#  'J»\x8eÅýåÇ',
#  'ÜðO',
#  '\x1c¡\x08µ\x16¹B\x0ekPÁÏu\x12Êïét@{',
#  'ã:\x85e½ø\x1a\nk/\x1e\x8d\x0eKàu',
#  'N\x05Ó',
#  '\x95Àu\x06\xadõ',
#  'Å\x1aoð°BC\\\x01º8U',
#  '9{q®LD]{Å\x85\x89Qí\x98÷',
#  'ã\x96',
#  'u¤R«Dw\x9d¼¿\x9d\x90bµ¥Ôÿ\x0b\x02\x1c ',
#  "ÚÆ¼ã4t\x84'\x11í\x99¿@;",
#  'Lqf[RzÅ\x9b\x18\x17IÊL\x0e',
#  '\x9cø\x90\x0fªÜ\x0303©\n\x0c\x81',
#  '\x02X\x13\x8f¸væõ&© dK\n®\x8e',
#  'qëHÿýº¾',
#  'xâu2dB\x83jÏÅÒáÀ»l%\x80',
#  'a?,`l\x9ck¬XÑö4àÙò\x95!È\x95',
#  '\x86\x8aabT\x01æô\x87\x13Q¨ÍÇ]/Èr½ä',
#  'C\x16r\x9dN\x8aÝµòÏ3²\x12©¹$',
#  'b¯_S\x8eO',
#  'Ð \x92¥\x87rÒ\x07Ê',
#  'È,_Å_ÍQ\x9f\x0cb',
#  "gá'O\x941kßö\x93\x80rý\x1a©Ý!X\x0e\x95",
#  '\x16',
#  '\x81s¢pªJå§Â\x17\x12\x12\\·\x88LrÞ&',
#  '\x92ñ\x92\x9a%\x7fhêsma¤\x15©#±wjn\x9d',
#  '\x9cÚ\x96\x02\x9d\x99u',
#  '~õ\x82t+\x059Rm7F½<ªcû`k\x88k',
#  'Ú¯\x00G\x8aâm\x9d<Ýµ%\x0f\x8aIª',
#  '\x86\x83\x11\x81~hÈí',
#  'B/é;/B\xad5',
#  'ã¥\x04¾\x10ÿ,íß=ë',
#  '_¬\x9c\x96èHú\x1c¬h',
#  '\x802\x8c¥á@\x06f',
#  '¥L)Üy\x93\x13Z\x9bf',
#  '«\x0bl^aÅq\x0fÁ&=´¦.Ú*ð\x92 ',
#  '¨ `<ùòÑà«\x04\nÆ\x11',
#  ')L\x0fÈÍµ¤P\x8fÞ\rL\x95»è3K\x8a',
#  "E|×(§\x10X`\x01\x15'\x07>·÷ë÷",
#  '\x98',
#  '\x10OZ&w\x0eA6\x1bK\x87¹³/',
#  '!ã\x95\x8eÅà¾øÑA\x80\x8cÝ÷\x07',
#  '\x81¨9£±ëRN¥Aye¤ÇR\n]Å\x1d',
#  "éÅ(ì'Ú",
#  '÷m-Õg\x13ï\x0b\x9bâ',
#  'Ó½nE{',
#  'n\x8e¨\r\x85Ñ',
#  '\x9fÇ\x07³\x92;MÅFJn§©\x05nUjÝÌñ',
#  'SÁ\x0f\\',
#  '\x94Þ±V\x97!æCè;%\x19÷G3',
#  '"\x9bmêÃ¬\x14fyùD¿wà¸ø\x11^',
#  'U¡Ö\x04\x88à]YBaÇ\x95\x11\x99àø\x1açz',
#  'pÁ**ü\x8a\x90\x1d\\\x06ò\x1cû\x06\\7F6',
#  "Ì*Ç\x06\x8b&ÍÇ½W¶0\x81\x81\x95\x83'\x8d",
#  'Yq\x04',
#  '9õÞÆÈnÕ',
#  '×\x0cÏ°\x05\x0c',
#  '\x91òþü\x02\x1có\x9e£\x1e\x89\\ÎõÉ³Ä',
#  'þÉkM\x08ïù%ð;ÏC\x02Vÿ>ý#',
#  '\x94s=\x9b#\x8fø5bÐ',
#  '\x90õ\x8dKÛ¾â\x80o}',
#  '>o\x00\x85DÜ\x96@7¥¡²\tp\x07\x15',
#  "\xad\x86êd\x92¦?8\x84'\xa0þú\x04JÕa",
#  'ÿò',
#  'ËI®\x92k\x99õç\x126\x9cÛ\x97',
#  '×\x82\x90ø\x90pí{Ø"Ò¶6×/5u}',
#  'Ø',
#  '\x95Ïx_³Ä',
#  'MqDùö}!\x0f\x9b°Èy®mù7\x86',
#  '\x84}tÆ\x85yÑqcí¾î/¨\x80',
#  'F\x00M;º\x9bËP\x9dÊ',
#  'Mêv\x99>Õ@X²ÊrÍÊO',
#  "í\x9cÙC\x1bGú\x1fö&ÃWýþ\x06'Ú¦\x03",
#  'Ü1',
#  '\x01=ù\x87"\x15Ï\x9cÞJ\x1b²jdZ\x87Ê\x95à',
#  '½"o\x91¼a\x96\x86ÊlÒª\n',
#  'ç=k\x12',
#  'Ý³\x9b\x11Jñ\r',
#  'ý±l\x03\x0eÞ×rù\x02æ-$',
#  ')®\xa0¶21SÝc%',
#  'q',
#  '§\x00}\x18\x88¦¬¬æìÅíYÅ\x10P\\èþ\x0c',
#  '\x11#\x1c¡ó\x1cp\n\x87\xadw+',
#  'ú\x96Ç9ÿò\x8a¦ßBð\x83\x96\x9c÷',
#  '5t\x8c$',
#  'IÙ_J¤ \x10bÓõ\x08ôr',
#  'Õ\x8co¥6u\x04\x93§;;]W\x89OéY_Ë',
#  'Qv\x01mÔË$Çò\x84',
#  'gHð\x10\x9fÆÄA¯',
#  '´Ç¢',
#  '3Iê#xÃÑ{ß\r',
#  'nhÝ\x16M\x86\xa0øY',
#  "Nf\x16'Ü&xù´M",
#  "×ÂgyÉ'",
#  'ò\x12ôÙþ\x01Â^ö\x8b\x7f\x1f:',
#  '\x0c:y~\x80©NÎ£6òXZË²',
#  '¸\x8b1ê\x03\x9aÖ',
#  '\x8a3\x12Q³ÿYÒ\x1a"MV\x1d5}',
#  '!ÁDÇ<\x9aSØ',
#  '#\x87þ)ý{\x9cÁÐ',
#  '-iWÄ\x0bu¾o§',
#  '~\x08|',
#  '\x1aDîãUr\x9e2WÂx\xa0',
#  'Ã_\n',
#  'Q Aß\t\x19+k1è\x81ç\x93éÓpéÃï\x84',
#  '±',
#  '\x1cý\x9c',
#  'ñY\x01õ%\x03õf\x84',
#  'q\x11E)\x99¯pû',
#  '\x01\tÀeAá\x94©ZP]',
#  'ÏçR\tÌ',
#  'ôÎ\x1dLé)\x1dYòÂ2M\x14,û',
#  '\xa0ýÌWP\x8533§U\x07',
#  '\x97\x90ðsøÞ\x16¡@',
#  '°X1\x17\x8cW|^êµõ\x90\x91\x1e\x91\x06\x8f\x12w',
#  'U\x01;i@\x0bÇ\x8e:¦*\x85(&\x08v\x92S«\x8d',
#  '\x93',
#  '÷¢±\x8dZ\x92%\x82¦¡øgë×ø\x9b.R',
#  'eK¦©¤®\x8aUþ\x9dÂrôñ\x04',
#  '1ß\x83FP\x1d<»CÇ\x9f7B',
#  '©\x00\x8cìèú',
#  '\x1b1K\x93²í|\x9dMo¡~\x87',
#  'Èuî\x9dõk',
#  '\x121p´Õàðg',
#  '¨¸',
#  "(X5ø\x82I\x000\x8bÕÁá\x9b'!\x87<",
#  '\x89ömðæûqn Z[\x0f\x05ÅÐlq\x06',
#  '£ýÆÛ',
#  '\x04Ñ.`\x82o\x0eí\t·\x07Ç*Ø',
#  '²\x0fÅ\x94VÁö',
#  '\\|6P¦\x82ð\n\r',
#  'fU\x08\x8d\x0ffç¦\x89{9',
#  'çÎ"P\x04¥aøJ',
#  '\x1fÕ§\x13½+Ò#vkßkwsö',
#  '÷5\x95\x98X¢\x89',
#  '4i¢ÈÅý>ÙòØá\x02',
#  '\n&[Ë',
#  '\x85Ceú=øÍ8\\y\xad',
#  'À\x00\x97õI\x8333Í\x01{?¢',
#  '=',
#  '\x9a\x87/K{Ýÿ2\x8d',
#  '\x87\xad>¶=\x82ÜÊáøã§\x14¡\x9c(\x85\x8d)',
#  '\x13´\x1cÓ¯Ïæ\x14Îþ®ñ',
#  'þÑ1\x9bC,\x1b\x17êýV®Z',
#  'Mr\x97Èç\x04µÇ±øp\x9cA8å',
#  'Â@\x95é\x00Ò§\x10¢',
#  '\x9eÅ\t\\pì&|V¨¥ÇíÜ½C\x9c*î',
#  '\xadÂP¾Õ£S§À\x9b¡ý²',
#  '\x06\x8a\x9a\x8a=ñÊ',
#  '\x85ÈÓ¡m[EËµK\x8eâ\x10>',
#  "\x13Ã\x93²ò\x87¸\x8a\x1a/\x12'",
#  '`\x88;\x01\x1bb²\x07æ\x0c;\tô',
#  'Ã¢(\x1aíäy#ÎK\xa0',
#  '\x95ö\x91tí\x1eÿåm¿NT',
#  'I¡ùÊ+Ú1aK¦\x0f\x86î',
#  '&åcØ=\x90õr\x9a\x9b\t,&ä',
#  '\x06ÄÈaàD8[',
#  '\x80w!U\x94sïQ\t×»:h$ÓÚ\x83\x94',
#  "Ý>d}å\x1e\x08[\\:fÈys©'¦\x1dg\x1f",
#  '7«ËÂh\x90b\tñ',
#  '\x8dØ\x16\tÀ\x1b\x14§kR',
#  '0qpV\x98g\x07!ËB\x19\xadÅ\x93',
#  '\x96)¾\x03Ù\x1fè°\x1a[Ù°Ê=O\x90Ï',
#  '\x0e\x93o\x9czj¤h\x1cSCþ\x8f\nK?y',
#  'g©©2\x98ìHq©#VÄÐE\x86Ê\x1e©ê_',
#  '\x91þÉ#2',
#  ':Bc\x17£\x1dï\x91)Zª¯e4',
#  'ÌôÐ±²xX\x12\x9eb5dY T{¬',
#  'Î\x0b¨\x10M',
#  'èð\x86\x0b×',
#  'ñæ\x92\x1a\x8e\x16H±\x00âÝ\x14vO\x91',
#  '\x03¶\x02C3s×\x15',
#  '\x96ñb\x8dG+´÷§F\x00\x04Èëx¸³\x84²j',
#  '\x9bÉ\x19ýË)*1\x18M',
#  '\x80\x1cûz\x04\xadb\x94',
#  't)äv¥\x14',
#  '\x1d\x95ÆHO¬ìåÈ®6B\x9cQÖA',
#  'ûµåZb',
#  'û´c`äú',
#  '\x07\x96',
#  '4¸©K~eÍ\x19ü¤«\x0fw',
#  'U¼Å¬Ìú`',
#  'öR½üØõ¼p®ã+üz¸ï9\x1e\x94¢\x19',
#  '\x8a§dfÿ\x83TU²}`½\x1c',
#  'I\x1dí\x1f@2îÙÁ¯\x163#ë¢\x1cYR° ',
#  '\x91',
#  '\x91¤&Pc¦\x0b¿\x07æÉº',
#  'çù-\x8eu',
#  'C',
#  'ª°S½+e\x1f\x81l¹l\x97@\x00eÍp',
#  'cÕ\x89ý\x0cî',
#  '3¯îþ\x80¿Û\x86Yú8\x11Þüüù\x85\x0f¸à',
#  '\x10\x1eoä\rE)ÿ',
#  'Í\x1a*ô6\x84\x87¨Kqï\x0eªì\x14\x86\n@\x9d;',
#  '¶MtÒpÿl\x8eä\x99\x1fv$¶R¯',
#  "òÝéH¦\x0f\x8dÞN'¨\nº¹·2ù",
#  'Pk\x18²',
#  '\x97ôÄá~«|HnWØ\x86(×f\x18\x02©\x16*',
#  '1¸u0\x7fÃìw»GÄk\x7fó«\x0cGu\x90F',
#  '\x83øÚ\x16?,&³\x8clÞCSÂ\x1bT',
#  "¡dd'Ì\x88±¡;",
#  '\t',
#  '\x17+\x97\x9e£\x9c\x19*¦v',
#  '\x02?á¾~\x06c5(\x11\x1cï',
#  'Õ\r\x07Í®s¶ë/¨¢',
#  '\x11}¥\x0e\x08\x02',
#  '55\tþd\x05_',
#  'î×ß',
#  '\x16ü¬ÒÀ',
#  '½áäºÍ\x145PQ\x1bN\x88',
#  '7a¢\x9eÍ\x1fT\x85\tôè\x85\x0f\rD9%¥/',
#  '#¶\x9b',
#  '°',
#  'Ý²cà\x14Ù\\É¬\x19\x9bwÇ\x8e\x18\x01ÛpÅ',
#  'R\x01',
#  '[=ÎÒÛ2',
#  '÷\x7f^ó\x827¢LÔþn\x88êK',
#  'Ü¯³\x80',
#  'ï\x8dß·ÿlwö\x88ð"',
#  '~®\x86\x8e3ªÕÀæ\x91\x0br',
#  "v\x86·\x9eµ'ésÃóB",
#  '\x95\x85f\x93LÓ\\\x9dPf',
#  'OYúE-',
#  '_ËÊ',
#  '¸Ë\x9ff4\x89^!U',
#  'áãk»ÍJÎk\x95ªF\x1c\x85\x9dÐe1ÐL',
#  'z^÷Z"\nÖÝ}G÷å\x19Y\x0eç·U®õ',
#  '\x81õ¸\x1a\x9cË\x95¾ÿE¸;7P',
#  'Ù#**]V\x1e©\x19W\x08',
#  '¨"f\x16¸Ý¢³\x07\x9a\x82Õor«!\x0b\x9b',
#  '\x99',
#  '¤\x07I`ãùÔÂ²\x9br>I\x92*\x01',
#  'cõ¾íÊì\t\x8f\x8bhªyr\x88Y\x04\x93\x99\x13¸',
#  '[ºÚ9ëö¡³ÓßÙ\x9bÝ#»ÞÝÂ+\x95',
#  '[\x8cü\x18\x05Æ#w2',
#  'D\x8dP9z\x07\x82¤ ?\tö\x97',
#  'ÆûÕÕI#\x81Í¼½ì\x10k]\x9c\x88\x93ÅJ\x97',
#  '|´Æ\x87 <_',
#  'Å5',
#  'GÍDC\x0bLùI"ÿVÖ8Jú',
#  '`u\x85\x10\x19:µ\x03×@w\\ÉÄ×\x82¿S&²',
#  '\x02\x16ÌtÏ\x10',
#  '\x8c\x17\x0eÆh5M',
#  'ú\x0c?D37´záM\x99¶\x9e\x94°3ç¥Ê',
#  '\x04²\x82øù¬ý\n',
#  'Ö\\eq\x82',
#  'Ä\x81H©ó',
#  '\x9fJ\x9afÞ[J>\x7f*',
#  '\x86\x0cªëÚ¦è\x81¤{\x11',
#  '£5ýüß-üE)»\x7fs±¶\x1e\x01\x92KÐÂ',
#  'ô\x95\x18?ÒLµë*ü',
#  'V',
#  'Á1¥\x86\x81å\x08',
#  '\x10å\x95åà',
#  '%\x96P\rõ\xadk¯í\x85\x07¿ª(ä\x8ao',
#  'iu\x13¤%\t¬94®\x85\xa0 zoÏ"',
#  'óï',
#  'ÏXÝÖÏ;à}',
#  '$¨TÃq²ìêåpASG\x8aÑ4Ä',
#  '\\*',
#  'n6¢?',
#  'e.u',
#  '\x10¨»\x89Ø[k=ð+mÚ¤÷',
#  ':\x19i`¼øwG',
#  '`f\x10jc',
#  '\x90f\xa0\x0b\x9f\x88¿\x02\x9c²ö\x9dOä',
#  '\x91\x05ú\x1dL,a\x1fÊ\x8f°99T\x93B',
#  '1l',
#  ' \x1fFIÂr¥\x8eq\x8cm',
#  'uR\x91fè<',
#  "ßE²\x04o'0\x9fÓ°qs¿Ê",
#  '¡å\x9b\t<µ\x04áO½à',
#  'E£\x17ã:@bÙ¡\x1f',
#  '²}\x02cT\x8aT\x1f',
#  '\x00 _\x9d\x1eÔ\x0b½À®£PE',
#  'X\x9cåÂ\x06%Çþ\x18°',
#  'öI\x15\x06/\x8a',
#  'ñÑ',
#  'ÉÙeØ\x11Ä\r\x19b`½cäÔy\tT\x03È¤',
#  '\x01\x1bòZüñ',
#  '²',
#  '\x98<lß]\x9e\x02H6\x82]³\x1aÁN',
#  '\x05SÆÕÌ\r§´ô¶\x0f\x0cRï\x11ÉÚèx',
#  'ù)\xadÏtÇØ\x9a\x9348çÛd\x8f&',
#  '\x02Ò\x00Ê-0Td"ÅûØQºÚí2',
#  '}?Î\x88ìñô\x80Ñ\x82\x1cã&\x8eZ',
#  'YÑ³;(ó',
#  ';¤%}\xad^ì0\x0c]Ï¨ê²à\x0b',
#  '\x9f',
#  'ý',
#  'ËÑÒ\x9eÅÆ',
#  '\x93ü\x05',
#  '¶',
#  '¹×þô',
#  '~Õ\x14\x12»°qÄ\x8dRß\x91\x13£',
#  'a\x14',
#  '8\x9a\x82\x9f',
#  '\x1dö\x18±÷ôñD#n\x97äö',
#  'o\x9f\x08\x87ìó\x80µ',
#  '\x9dÆ¹ñeðs',
#  'Á\xad\x15U À\x91\x82\x82f',
#  '¾',
#  'Ùu\x83¹R{}c£@¦[Éà',
#  '\x92\x9eZ\x9e\x80',
#  '\x8bª7¢Õ\x18È>»Ù¦\x9c§\x10`\x11/\x9d',
#  '\x83\x02\x9b\x0f¤µ\x88',
#  'ÍRÉ\xadÝ\x84X\r\x1dªÆðul{',
#  '\\',
#  '\x0cçÔ»r?ã\x82',
#  'r^z',
#  "\x97ú¯F\x0fÒj³\x083Û(r@d'f",
#  '\x1dtá½Ä¥ÁÌ´V',
#  'Ðò$',
#  '¼ÝSk`ß\x85\\K',
#  'ôìJ\x1dÍË\x93\x83ßºô«\x8dw09\x1a\x86|\x01',
#  '&\x8fé£\x98\rá )áà\x0f¥8',
#  '×nA8Ì9ïWFV',
#  'ÌÊ&y',
#  'ÂÂO\x1fÌc',
#  'ò¿¦Qï¢îÊKH>»âJ\x83eîÐ\x90x',
#  '\x02ò¤Ç¸\x9bô\x065',
#  '\x839À\x0b!\x9bE\x19{Lw\x8b}',
#  'É\x8eéÜgÎ@Î¼Vàóü',
#  '\x92\x94]`\x90²F¯',
#  '\x0eúX\x10ae¹',
#  '\x05ÿÊ´',
#  '%\x05\x90\x1b¶¸¶\x186\x02)J\x10\x0b',
#  '\x99Ý\x13\x0ez7',
#  'L\x8a:Ù¦âÝy\x0e\x02û\x05',
#  '\x85\x18\x05¯Döòís\x9c/õà\x88&\x05Ä\xa0\x9d-',
#  '9LÕ¸ðú\x94þF[Á9þ(\x0f®üu\x99',
#  '\x89',
#  "1_\x88%q'H+8\x19æÐà§",
#  'í}F0j\x1bîR&ë~ÍÆ¸&\x8f\x96¹\x84\x18',
#  '\x80/±öÍ¢¶',
#  '¤\x84ä&\xad2e!',
#  '\x83\x19[\x02´ªB\x12\x1az',
#  '÷\x11þlAíöÛ{2;TËÖ\x82',
#  'C7\x16ÀÓa\x9eÌØdÞN´\x8b',
#  '"-\\)\x00¢Ù\x08\x0c/',
#  'ÿ¼o',
#  'ò\x8a%zÁ\x95| Á¯ºÍªD',
#  '\x0c\x1a\x8bÈ\x87¾Ê\x9f"Íôå9Å\x87oµ©ªr',
#  'ë\x8aâ\x1aµRÆØê\x17\x87,ÌÉ\x080\x99',
#  'ä\x8c=`J\x82\x99\x19{Y\x08CÖê6\x87',
#  'êó¯dP±\x83Ô\x82\x19&F\x8dÞ>+',
#  'Æ',
#  'Óø',
#  '\x9b\x98Bô\x08wÌ\x9aYÄyø\t±Ñ¸~',
#  '\x0e¯·É,4\x95\x97ØÆ',
#  '¡',
#  '¶X\x8b\x91@ë´ß\x14ñ\x19\x84\x99ä\x94\x7fó\x03id',
#  '\x12@\x06%\x05\x82âªÜ,M\x84',
#  '{rÂ\x16®Z\xa02VB\x05',
#  'âMð7å',
#  '\x1eÌ81\x90\x8fÈ',
#  'Ì\n\x0c\x85',
#  'ÈW±\x96\x93',
#  '`\x82\x1fJ',
#  '\x7fæ\x893\nL\x12\x8f©£|yýÿÄ^\x1bS\x19',
#  '\x1a\x17|mµ\x1b¯',
#  '~\x10\t\n\x0e¡ëÏe\x10\x1a\x0f{\x9b£\x0eò',
#  '¯©ì\x8b\x85ª=\x1c',
#  'ûè\x13\x934',
#  'ÜwY\x98\x98#,»Ô',
#  'vÆòÑ}|\x18ªr?Z\x1e¯',
#  '.|\x9f\x92Ó\x94\x99Ãl',
#  '$\x1a×',
#  '\x05\x13rú',
#  '§N±',
#  '¾k!B·ßp\\SÕ"\x9d0*Å\x84ü$',
#  'X4¯\x97\x80Ï',
#  '\x98\x15\x05\x92r\x98G\x1a¢EMÿ\x9d',
#  '\x18KÖr',
#  'x',
#  'Ó\x8cÿò¶',
#  '\xa0)\x17³x\x0ef\x7f',
#  '[U|\x06¼\x1a',
#  "ÅÚÏ°&\x82áî*PáQ¢|:Âá'~",
#  'ùK¯',
#  'â\x99Ë9¾§',
#  '\x19²t\x15./hôö\x88\x11÷\x83ì',
#  '4\rX<Åw',
#  'þ',
#  '-\x95',
#  'L\x8d³Ép-¥ÿ¨&Ò\r\x072\\é',
#  '\x9ae´\tvã¶/\x18Ð!\x0eY.\x93q@Õ',
#  'Ô\xadð8©h~YT\x18k\x87^\x0f³',
#  '\x96\x14=',
#  'Ë»½g7¯qÚUuDð',
#  'Ý\x8aKÞjê|¤½~\x1cA',
#  'L',
#  '\x96ù',
#  '\x92P\x981s',
#  '¢\x84u$Ò\x11QD',
#  'Jz\\¥gn\x9eSsÄ\x08F5Ixùz¾\x99',
#  'º',
#  '\x88Ýã2à#Ú5sîNf^\x85Ë\x83K\x06',
#  'èw\t´ÊÓÌËÉ!Ej\x90û\x1cë»6Ô\x8b',
#  '\x1a\x18d9ìU3*Ô$èÂ',
#  '\x02\x7ft\x8c;\x1dÃpqÉ\x1b',
#  '*ëÆ\x81t\\Bé\x11è[\n\x97\x8e\x14L¤j;è',
#  't|\x1dTæ÷þ.\x000áN',
#  'B¯¥',
#  'kö\x1bæ\x9b÷\x1dÊ\x15\x08ÛIIRë¸',
#  'w\x00oCp>èY<FõJ¯½+¸',
#  '\xa0èQÈ`90',
#  '#°\x83\x9e\x97\x95«^?Bp\x83uß',
#  'd\x85\n\x96º^\x95\x07ÒTP9/:]EÐ',
#  '1\x1a\x95\r\x94',
#  'aÎËì»\x9a»]K\x9f\x94óÔÀé',
#  '\x85\x88z*!`>ÈÑ',
#  '*¼\x9a¢ö',
#  '\x19QC/;²\x9fR[0',
#  'ª\x8f.Ï\x05¦õ\x1aÅÿÐ\x8ed\x85ÍSaÂo',
#  "»çR\x86ý(\x83¿'ÆôÚÙ\x05þ\x7f\x80&!",
#  '\x13\x97¸´',
#  'ý\x98Úc\x90DL\xa0',
#  '×\x1e\x14\x01Þ\x06,g¸î¼\x7f<ë%[¿Ó',
#  '\x91\x1deøjTè5\r',
#  '\x16}',
#  '¦=°\x9b',
#  '\x8dÎ\x941\x10y¼éãF\n±',
#  'íâænÍst\x13nn\x8am\x96é\xa0n\xa0=à',
#  'òë',
#  'HY¼Q\x1d\x058X£«\x89',
#  '\x12~ðH\x19±ÏþÏ\x9eKÆu',
#  '\x0fhÊ\x05\x01\x0e\x14XÏ\x85ÁÍ',
#  '1',
#  'öc!Ç\x83',
#  'À\x18?\x01\x1d^\rI±å\x1d\x13',
#  'Å\x0fP\x18zI\x9az\x12«àÙ;',
#  'ü(\x86\x80S\x8eÓÿ£\x15\x81ð\x07ç\\\x81â¶08',
#  'Eªn\x14\xa0 \x089',
#  'd\\\x9c\x10`2Z\x1a¼µ2\\',
#  'd\x1då³ð+ª',
#  'å\x11\x9d\x94C\x91',
#  '\x89(\x14\x82\x9bI!Üª\x05%C\x19\nB\x04åC\x8d\x80',
#  '\x82\x1b¾~£\x19ù\x8aºï>\x86',
#  "{7Ç<\x99\x01³ðáëï%R,\x8dÐ'",
#  'køEä´.\x06\x00s$;o\x1d1¸â',
#  '[D¤\x16Újhð,p\x80\x1f]Óªð',
#  '\x05ù÷\x9a°nmÍ',
#  '?G¥8n',
#  '6ñ<ôön\x14\x88Q\x9b',
#  'gT°/0Çýp1',
#  '\x9c\x01\x94¶õFþ!\x1bâ\x19\x1f',
#  '\x1e«ÿU<+qíú\x8c¤â+îS',
#  '@d\x1do\x9e\x06å÷qî\x81"',
#  'éê\x7f\xadN\x1dj\x17ÌÜ\x19ØEp\x88\x11¢A',
#  'Ã·å¼O\x18¼G\\4\x7f\x92£*',
#  'Ð¹\x92\x92',
#  "ºïü¿i¦}'p}T\t$pØ½",
#  '°\x96gñ@ÄûO\xa0a\\{êD¡',
#  '\x9b\x19´*\x02\x0fx\x05ªsíá<',
#  "°b«o'~\x0cÕ¢\x90\x8ffX",
#  'É\x82¦ñq>\x94Ä¥\x9as',
#  '\x1f\x13\x1bRp\x90í/\x07\x0c¿µØm',
#  'B\x84À\x10x¤\x9bÚ¨y\x92\x84J',
#  'U´ë',
#  'ù¤I¡6Ñí\x16ú\x87k\x98',
#  '>\x14Ð\x8eaW½ñ\x1e\x88\x9d',
#  '\x00\x04qW\x17\x1b<#',
#  '÷w\x9c\x01.UK\x0c6U',
#  '\x19 7vP£',
#  '\x81\x9bÏþº´\x18À½a#\x14',
#  'G¥[Ò»\x04\x97E´ä',
#  'V¬>',
#  'Ze2<¢ï÷¢\x86\x14\x9d',
#  "|÷o\x1b²;'fë¨",
#  '¶[\x1eMí»þ£×\x00Ç=\x92',
#  "dÁzï](\x91ª\x05:B\x85ËÃ}'\x17[¹",
#  'Îì\x01[',
#  'w\x0b9\x03¨\x99%Z\x16èH8«ß)',
#  'áH\x13á\x0bÛp\x0eï',
#  '\x86¥±',
#  'æ ',
#  '7\x93i\x83\x1fåò\x9c',
#  '\tP3.\x94u¾ÿ',
#  'Xtúé',
#  '\x83\x0b\x9c¾Ù2',
#  ':x¿\x1e%à¹ëb;A',
#  '*Ñ8û6RU\x13@á\x10¶ý6ïg³9\x1c',
#  'C\x11\x89\x8b)Ø×',
#  'Ø±Y?¤\x9eõ\x0f\x027Hwä\x16]U',
#  '\x06µ4UýúÌß',
#  'Í¯\t®²Qb®Þ§\x13',
#  'Þú\x1d\x80:«²\x921C\x8aËé\x89QAà]H¥',
#  "X)äÑ'\x90\x0bØäm\x8bÐ",
#  '\x0f\x88\x81¼\x1e¤ \x99gÒfÛâDz\x0bH\x01?',
#  '\x0c\x19?|å\x12\x85R',
#  "`æ<±\x9d5\x85l<\x7fó±'æ\x93YD",
#  '½j\x83q\x11/p1Ø"Ç¡nvÓ)\x13\x10\x82¦',
#  'Wé{\x90{¶ìÈ7Û\x9d°',
#  'w´',
#  'apJwmH´×c',
#  'ÐÄs½Àoïw\x9a]Ð',
#  'l×È&ùrûüÑ\x07\x0bµë¶SÜ®\x8dó\x95',
#  'Âô\x1anÓu',
#  'S\x96\x06üÑc¯¬8-¡Èû§Æã\x9f0dñ',
#  'lÇ\x84\x94¶Å7ÅÝ',
#  'ã\x1b\x91SåÇ\x19Ë\x08½\x00\x97$ëÌ»',
#  '¯ª\x94¤\x9f¶¤ÅÞ5ã',
#  '1Uµ´¿¯rÿ\x12\x8d',
#  '·{¶f\x9f"j\\',
#  'g8\x910N',
#  '\x89m0\x0fh\x8e\x86»ÈS0Hì1d¹',
#  'É²(X\x8bNÇ\x1aÇ¢9',
#  '\x1bAR§\x86ß¤&.°m¡ñ5\x16\x12¢©',
#  'Ü\x81\x14\x8c\x8dö-ß:\x12\x82',
#  'î\x90\x80Öûûp',
#  'å%£\x0fRöS=K\x9cÀÉ\x04\x16fÈ',
#  '\x9a\x9aí\x94J)#V\x87`F;N\x0b\x1e',
#  '\x8b\x87',
#  '<î\x82µ',
#  'ÂH8)Þ\x13¬·qe\x07Í',
#  '\x9a\x9cêOá\x0c\x13',
#  ',u\x14zàk\x1d¢\x7f',
#  'º³\x89',
#  '\x03cÆÝØ,-yéK^\n}{¢H\x8bic',
#  '\x03\x9f\x0c=\n[ÿ',
#  '¸kÅùehb',
#  'º\x8aäÓJ"c',
#  '\xa0û·Å)\x06D%\x80Ú:ú1è\x115Þë;',
#  '+}øP=Óç\x11ª$)ma\x8eèÐ\x8asG\x91',
#  'Ix',
#  '\x16\x1c\x89L~>',
#  'b\xad³c\x99',
#  ',¡M XØ`ÐøFn¸¦&¡·_',
#  'r>É±,Åã\x8a',
#  'Ó§\x98Ç\x96',
#  'E\x03õ¬',
#  'à6i^ÿ¼\x1a',
#  'HßÎÏI\x81',
#  'ûH\'W\x02"g\x1a',
#  'ª',
#  '\x05\x0b\x91\x1b\x19Û(;bà',
#  '\x97',
#  'I\x03Ù\r',
#  'C8\x99\x94eI',
#  '\x7f\x14\x84\x1f',
#  '$Ý,\x1cÄæîÅMU¢eÒy¾DõÐCv',
#  'xgX',
#  'q\x7f%:ºÀ',
#  'U\rL&UàB+\x9cAít"ÀÚ',
#  'LY\x19p',
#  'Fx\x84\x05\x1dþo\x064"+¤á!k\x8f°',
#  'ò\x163\x02\x05Å\x84|\x03',
#  'b%V^5$y\x90JÕî{µ',
#  '£É',
#  '\xa0',
#  'æ¬\x8c\x9bû»\x1fø¬1',
#  'Ë\x1c\x1chJ\x91c\x86NÖcü\x89Å£\x98É',
#  '<\x9eÔ±bÀÝºÕã\x18\x8a\rÚ-k\x84[',
#  ";+\x12ï'(*",
#  'Z·\x17pf@Fý³[f',
#  '\x12\x95`\x88c8£Å',
#  'cöWC!\x18¿',
#  'Z',
#  ',\x18\rû»÷##â.',
#  '\x95;Ôy%F2\x8c',
#  '¿',
#  '±',
#  'GM',
#  'õ8£<Ì¯j_\x96\x96Ñlx´WÐ',
#  'ßà\x86\x81âÿÁ2',
#  'é6',
#  'A]¬\xadø\x85',
#  '\x89q\x151®HÛ\x12Ç?Gz=ª.ä£³è',
#  'Áæ"\x00',
#  '½È>:¡@\x9bQa',
#  '\x97\x91&\x0b±ÿyl©ä\x13\x85¾¶HòÜ\x9fã',
#  'iÀÄd\x90',
#  '¡\x931\x05æ¥°¬[O\x95£?ìc',
#  'BßÀrVs',
#  'Z¦*rs}ÂªR´}\x90É\x15¥\x0b',
#  'ýgKÀ°²º\x82¹É\x17\x07\x99z ',
#  "´4Ëÿ'\nS4\x90(®]³u)\x05",
#  '$\x9d¿ºz\x86z\x83\x99$y-Î',
#  '\x9d|\x89\x11¦\x1b',
#  '\x185\x13H',
#  'E\x9b\xad',
#  'ÎbÙ¸Ï|È\x90,',
#  '\x16%*zL\x93¥\x16\x9a',
#  '\x8bËæ<l\x10ÃaÛ8Ø\x16¦o',
#  '\x12~L;â¥0\x1fX*á\x00âÉ',
#  '\x80[\x90Wæ8\x94uÊ:\x14\x87\x86D\x03\x9aÌ\x05',
#  '\x8f"\x1c',
#  'ñ®\x08UMR#A\x1d\x13A\x84ï]ýô¿ø',
#  ',Ú\x0bL\x0f©`\x85L',
#  'ÿ',
#  'ä6\x85\x1fcþLeÃEÿEÝ¦',
#  'l}B\x9eì\x8f+',
#  'YìqüÆÌÒ',
#  '\tþjo¸\x1a\x99ãêáÝª\x92\x8dòÝ',
#  'âñðô',
#  "µÜ'hå",
#  '¶g\x81w\x16\x19,Õ¡\x14',
#  '[\x94½ùß',
#  '$w6üdjEöÞ',
#  'ï+h\x7fs\x06y53\x13>\x03n\x7f',
#  ',|³ý\x88\xad¨3¡8\x9a¿',
#  '%çóì\x1f°\x13e\x951±b\n',
#  'CãÔd',
#  '\x89\x9b¡ 0\x11öv5¨¶',
#  'pâN\x02ò\x06?ÚÖö\x92(',
#  'Sþï°ÿ\x13\x17ÊµZz"Ç+\x1e\x0bSn',
#  ';Ý\x8fa\x9d\x00Í\x90±Mó',
#  'u\x9ed}.öäî`\x08w',
#  'Q\x81+óB$!ñY\x89',
#  'ì÷Jökîú²\\°\x98=%Ü\x19\x14',
#  'a\t\x9c8¬¹¸ÇËÞê¨&',
#  'è6E5¿ã\x82Z\x18~jÓµ',
#  '7¡\nïss\x9e\n9\x8bÝàk\x05=`',
#  'tMø5\x06)6öTÕ\rÅÙ\x82Èw\x97\x92\x13',
#  '§\x8d\x9c>{1\x8eü\n£',
#  'ôf\n3¥Ü\x029:\x7f¶',
#  '\x98\x00\x00',
#  'W<Y\'"í-ûU;1\x99½\x91R',
#  'éy Ø\x19',
#  '¢Mé}ÂørZ`Q\x02\x0c',
#  '°¼üB¿É\x85µ/jC',
#  '.\x02P\x04\x0f',
#  'c¥9/F\x9f',
#  '\x80Äyi\x87 R',
#  'Ñ°_9®ÎÐg\x1b\x02\x99¢0¬¨Y®',
#  '\x88õ2\x03\x98Q5\x11%\x90\x1e\x10R(Ö',
#  '9\x19zhÊ',
#  '\x0c\x07º\x1cª¯\x1fB\x8eG',
#  'U\x8f',
#  'ýèxv¢ì-\x84\x1bÑ\x80uøÑ\x9e~\x95m',
#  '+|1<\tÌþ\x93G\xa0$RÍ',
#  '3\x91é\\ºÿ4_Í\x16q-¹\x1a',
#  'Úôº;',
#  'p\x90$\x9f\x86\x13§æ\x92\x99',
#  '\x1d\x86¤\\\x80®ÃÅÇ\x7fNG7T^',
#  '\x8a&#Çë?',
#  'â1ë%[´M\x88\x10',
#  '\x01að\x9fOfå¢ö',
#  '=ö>ñ/læ¶\x9cÚÛ\x0f\x88\x1cB{',
#  'uF\x83ü\x0fZý',
#  '^\x06,Ú\x1d',
#  '\x05vi\x11t\x9e\xa0á½\x82%òQ\x1a',
#  'V\x8f£\x8c~\x8c\t',
#  'àÁ¡\x1cñ×¾ÈEC',
#  '2JT\x1a\nÿV÷S©W\x14\x1eãÜ½Aþcµ',
#  'îÌùêc\x87\x0b¤÷¤ÀcÇ\x7f4',
#  '7Ç®ñòsn¡ëÜà',
#  'Ò\raè¾ÈåÛÒ~"\x85²\x16$',
#  'ÉMÝOðµw0HJd¯¹Ø',
#  'þËà',
#  'â¿>l\x87d+%½\x1a\xad\x8fÛ\x98íHÓ\x89',
#  '¨¬?®\x0b',
#  '®Ã§ÛSú£¤Äfà\x94\x91\x7f¹Q\x92z',
#  ';\x08}û4:GÓC?5\x0f¥¶)\x13àô;',
#  'r\x02\x92±Y9\x89§Ô,¿à¾',
#  '%\x1bh\x90öT¢d@®\x03I¦°\xa0\x8d',
#  'Þh©+Kà;\x7f\x82',
#  'ph£\x06\x05',
#  '\x9d½»',
#  'ã9\x15\x8b\x80\x8bh\x11¡Õø',
#  'èT×\x8d_¨8Ub\x06`ýL\r¦ÚF\x80',
#  '°4\x82â¤\x87',
#  'ãî\x81jì\x95\x92ðt',
#  '½C\x95éÍó+\x18©×3ÉkÑ0',
#  'lº·\x15³e\x9d\x04\x0b8Ù¼ó\x9f½¢\x1b®BÕ',
#  'áÍ,6i',
#  'USÌ¾\x01',
#  '«\x99çi9tÕá!d\x94wãñ!\x9fÏ',
#  'ø4?¸ëð²°ßóèÍLÉ\x1f¨',
#  '²',
#  'eÝô',
#  '\x82oú!\x10É2xÒÉÅ\x89Ý|',
#  'ùêÌ7\x95KÁ63ªÑ4\x07ðã|Ç\x00',
#  '2\x9dk',
#  '\n\x03DÖð¸«\rÌ[Q½¾\x9d\x97Èq+¶',
#  "Ë\x16¯%GA3-éó¿$é9\x14'Üg",
#  'Ä\x1a\x98 ÿ\x11',
#  '=',
#  '\x00',
#  '\n\x02ñx\x99ÎÃ\x16\x02\x85\xad',
#  '\x11\x95\x98§A)ð\x06ã\x98\x8d¶Ó',
#  '{ñ',
#  '¸NÀ=!Úd»°gøf£ó/;\x81L°·',
#  '\x07·Ûf\x84P9f\x13^â\x13ÃÆ',
#  '.\x99+`3.\x08£!\x13ÀWº\x0foOå<\x10Y',
#  '¦\x9f',
#  '÷',
#  '\x08@[²3\x02\x0e\x08%\x04\x14s6\x88c',
#  'ÀÃ\x1eä³',
#  'é)',
#  'gËÔüê\x12¹ñú\x0fæÁ«ù\x0fª\x8865¡',
#  'qÌ\x9b',
#  'å\x10ÓãÂîÊ¾ñ²\x8bð\x13',
#  '\x10X¯â\x97ij/2',
#  'Á\x1a¥\x0c\x84',
#  '*ô\x81S½9',
#  '\x1c\xa0ÖH°_¿Ø\x17Ñ¾ó\x88',
#  'ÓtEÃS$\x12\x02\x10',
#  '1c;f\x8eëM\x91l\x08A·\x96¹X½<\x15',
#  'Í\x9d',
#  'Å\x83ð\x87\x1cÎ\xa0\x95ÍÂßâ7$\x0cT',
#  "Ùº'B\x15\x8aê±\n+ÝKá}U",
#  '\x8dåù"@»a\x99µµ\x19\x10XõËû\x94\x08ºt',
#  '`]ù\x0b',
#  'Ë\x11ê\x92\x83\x1a\x84hb0',
#  'ÂÈÉ\x14Â÷',
#  '(\x1ee',
#  'Ã\x98ý_Ãü ',
#  '\x99Q\x9f¢ó"\x9c\x16µ;\x17÷\x8b8',
#  'ºüQÍmx\r',
#  '\x13[Ë^C¦OÓ]U',
#  '\x82Ûâ»\x98ò±1I\x1dðºþ\x95\x19Ä¡Mq',
#  'ö',
#  "#\x8d9\x11ä;\x0e.aµ0µÈ'\x01[_G,\x8c",
#  'è)õ¯²v\x80{D»',
#  'ÂÁ\x1ci+\x9dù°s+\x92',
#  'R\x82b"\x0b4d&Ln\xad\x99?\x8a',
#  '.@',
#  '\x96AZÌn©ñ2Ü\x17\xadýµ(¤¶$®',
#  'R\x9eFÔ\x18\xa0cÍ5\x19\x0b¬\n"Ïú\xadt\x16',
#  '\x14',
#  '=\x89:¶V»Å¨\x17\x04\nQ\rb',
#  '"_\x8b\x1e\x8f/¯{\x90ëò#Ù',
#  '\xadB\x82\x1cÉQÙQ\x92$\x94\x1c)y#Ð-Ôj',
#  'Áz\x1f%\x89¿¶_\x8c\x11½',
#  '®\xad\x87\x1d¹ÏàÈ¤\x15éÇ¹\x04¼5\x03?Z',
#  'òZ\x1f\x00Èë;\x85>',
#  '\x9fÕÜúÈã¼)\x91LÎ\x13',
#  '`)TqÝÀÿÄ=\x14Â»^ý',
#  'ºÎ£\x90f\x87¸',
#  '`£¨ÃyúB>Ä\x8eiª<\\\x91\x83ê\xad',
#  'y\x04\x9bÎm"\x99\x14(~\x0cî\x1cYR¡',
#  '\x00\x7fd\x8bF½lK\x10j\x14JiÞ¡(ÆâD',
#  '\x0f\nÍ\x93Î-}5\x1cx\x98æ\x902\x10À',
#  '^j+r8.\x95¾îà\x0etc}½Úª',
#  "/Sm\x18¦¸gH9©p'\\\x1bô\x1e",
#  'ä',
#  '\x93C\x83Ú\\\x17ÃLð\x95WäµH\x06èY:',
#  'Î\x19G\x87ü9!9ÕÇ',
#  '\n',
#  'gjóÚÐ:\x14T³',
#  '\x1aø%\x8a\x16\xadÃ]\x8bäJF(pñ@',
#  ...]

# %%
# %matplotlib inline
ys = [troff_runner.f1_failures,
      troff_runner.f2_failures,
      troff_runner.f3_failures]

import matplotlib.pyplot as plt
plt.bar(["\\D", "8bit", "dot"], ys)
plt.title("Occurrences of error classes");
print(ys)
# Out:
# [5, 90030, 0]

# %%
#Exercise 3:Run Real Troff
real_troff_runner = BinaryProgramRunner("troff")
for i in range(100):
    result, outcome = random_fuzzer.run(real_troff_runner)
    if outcome == Runner.FAIL:
        print(result)
